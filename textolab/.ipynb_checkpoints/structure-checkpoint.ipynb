# %%
from typing import List
import pandas as pd
import spacy

from phraser import Phraser

# Mapping spaCy POS tags to single-letter symbols
POS_MAP = {
    "DET": "A",     # artículo
    "NOUN": "N",    # sustantivo
    "ADJ": "J",     # adjetivo
    "VERB": "V",    # verbo
    "ADV": "D",     # adverbio
    "PRON": "R",    # pronombre
    "ADP": "P",     # preposición
    "CCONJ": "C",   # conjunción coordinada
    "SCONJ": "C",   # conjunción subordinada
    "NUM": "M",     # número
    "PART": "T",    # partícula
    "INTJ": "I",    # interjección
    "PUNCT": "P",   # puntuación (no es utilizado)
    "SYM": "Y",     # símbolo
    "X": "X",
}


def build_structure_table(phraser, language: str = "es") -> pd.DataFrame:
    """
    Construye una representación estructural desde un objeto Phraser.

    Parámetros
    ----------
    phraser : Phraser
        Una instancia del objeto Phraser que contiene las frases del texto.
    language : str
        Código de lenguaje de los modelos de spaCy (e.g. 'es').

    Retorna
    -------
    pandas.DataFrame
        Tabla con las columnas:
        ['full', 'len', 'wordlen', 'minimal', 'pos']
    """
    nlp = spacy.load(f"{language}_core_news_lg")

    rows = []

    for phrase in phraser.phrases:
        doc = nlp(phrase)

        wordlen_repr: List[str] = []
        minimal_repr: List[str] = []
        pos_repr: List[str] = []
        sent_size = 0
        
        for token in doc:
            if token.is_punct: # Solamente si es un puntuador entonces se transcribe directamente.
                wordlen_repr.append(token.text)
                minimal_repr.append(token.text)
                pos_repr.append(token.text)
            else:
                sent_size += 1
                wordlen_repr.append(str(len(token.text)))
                minimal_repr.append("w")
                pos_repr.append(POS_MAP.get(token.pos_, "X"))

        rows.append(
            {
                "full": phrase,
                "len": sent_size,
                "wordlen": " ".join(wordlen_repr),
                "minimal": "".join(minimal_repr),
                "pos": "".join(pos_repr),
            }
        )

    return pd.DataFrame(rows)

def text_to_structure(
    filehandle: str,
    language: str = "es",
    to_csv: str = "",
    to_tsv: str = "",
    **phraser_kwargs,
) -> pd.DataFrame:
    """
    Wrapper conveniente para construir la tabla directamente.
    """
    phraser = Phraser(filehandle, **phraser_kwargs)
    structure_table = build_structure_table(phraser, language=language)
    
    if to_csv:
        structure_table.to_csv(to_csv, sep=',')
    if to_tsv:
        structure_table.to_tsv(to_tsv, sep='\t')
        
    return structure_table

# %%
a = ''
if a:
    print('ehllo')
else:
    print('Bye')
# Out:
# Bye

# %%
text_to_structure('../ejemplos/manifiesto_hidroespacial.txt')
# Out:
#                                                  full  len  \
# 0   Manifiesto La Ciudad Hidroespacial De acuerdo ...   25
# 1   La arquitectura engloba necesidades elementale...   20
# 2   Hasta ahora sólo utilizamos una mínima proporc...   26
# 3   Es decir, el departamento o celdilla para habi...   17
# 4   Sin contar con la decidida repulsa de los arqu...   53
# 5   Pero las estructuras sociales y los mecanismos...   31
# 6   En la revista “Arturo”, 1944, expresaba: “El h...   55
# 7   Mis diferentes etapas en las artes visuales nu...   23
# 8   Aunque asumo mis propias contradicciones al cr...   21
# 9   La premisa es liberar al ser humano de toda at...   14
# 10  Esta transformación adelantada por la ciencia ...   37
# 11  Una imaginación transindividual y sin metas pr...    9
# 12  De ahí que el primer proyecto o enunciado de u...   42
# 13  La aventura de la humanidad no se detiene ante...   11
# 14  Al contrario, vamos dirigidos hacia lo descono...   22
# 15  Estar arraigados en la Tierra , o para ser exa...   61
# 16  Proponemos concretamente la construcción del h...   34
# 17  La arquitectura ha dependido del suelo y las l...   10
# 18  Dichas leyes pueden ser utilizadas científicam...   24
# 19  Intentar la construcción de algunas viviendas,...   19
# 20  La opinión de algunos astrofísicos e ingeniero...   42
# 21  Energía capaz de mantener suspendido el hábita...   31
# 22  Así pues, no se trata de vencer las leyes grav...   16
# 23  Por ello me dirijo a todos los científicos de ...   15
# 24  El costo desde luego, es muy alto, pero con só...   30
# 25  La arquitectura hidroespacial está condicionad...   12
# 26  La vivienda nómade hidroespacial deteriora el ...   23
# 27  Apunta asimismo a una apertura del arte, pues ...   15
# 28  Se propone pues, un arte de todos y no un arte...   13
# 29  Al superar todo intermediarismo, el arte se in...   25
# 30  Los lugares creados con sentido de síntesis y ...   13
# 31  ¿Para qué, entonces, la pintura, la escultura,...   35
# 32  Más de 4.000 millones de habitantes de la Tier...   19
# 33     No hay civilización por generación espontánea.    6
# 34  Los Mayas, los Incas, la cultura China y de to...   32
# 35  Nuestra civilización es la mejor porque la est...   28
# 36  El arte como “Canto de la Historia “, “Moneda ...   49
# 37  Debemos reemplazar a las habitaciones que se h...   33
# 38  Si, dentro de un espacio, pero ocupando el esp...   13
# 39  Y no como una alteración de la aventura humana...   19
# 40  Probablemente aparecerán otros condicionamient...   51
# 41                                ¿Idealismo utópico?    2
# 42                                       En absoluto.    2
# 43  Los que no creen en su factibilidad es porque ...   19
# 44  Por lo tanto disolver el arte en la vivienda y...   19
# 45  Los centros de poder y de decisión económica y...   45
# 46  Contará con nuevos lenguajes no solamente para...   17
# 47  Un lenguaje enriquecido por puras tensiones y ...   12
# 48  Desde luego ser habitante hidroespacial tendrá...   28
# 49  Finalmente la vida cotidiana no estará solamen...   25
# 50     El ser humano en definitiva no quiere morirse.    8
# 51  En la célula hidroespacial el hidrociudadano e...   38
# 52  Hidroespacializar, aterrizar, amerizar, aluniz...   18
# 53  Habrá lugares para tener ganas, para no merece...   48
# 54                                Buenos Aires, 1971.    3
#
#                                               wordlen  \
# 0   10 2 6 13 2 7 1 3 8 1 10 7 , 2 9 2 2 6 2 9 10 ...
# 1      2 12 7 11 11 3 9 1 2 2 11 10 9 3 2 8 2 2 5 6 .
# 2   5 5 4 10 3 6 10 2 8 10 8 , 9 1 7 3 2 6 6 7 2 2...
# 19                            wwwwww,wwwwwwwww“ww”ww.
# 20       wwwwwwwwwwwwwwwwwwww,wwwwwwwwwwwwwwwwwwwwww.
# 21                  wwwwwwwwww,wwwwwwwwwwwwwwwwwwwww.
# 22                                 ww,wwwwwwwwwwwwww.
# 23                                   wwwwwwwwwwwwwww.
# 24                 wwww,www,wwwwwwwwwwwwwwwwwww,wwww.
# 25                                      wwwwwwwwwwww.
# 26                           wwwwwwwwwwwwwwwwwwwwwww.
# 27                                  wwwwwww,wwwwwwww.
# 28                                    www,wwwwwwwwww.
# 29                   wwww,wwwwwww,wwwwwwww,www,w“ww”.
# 30                                     wwwwwwwwwwwww.
# 31   ¿ww,w,ww,ww,www“w”,wwwwwwwwwwww,wwwwww,ww,ww,ww?
# 32                               wwwwwwwwwwwwwwwwwww.
# 33                                            wwwwww.
# 34            ww,ww,wwwwwwww,www,wwww,ww,wwwwwwwwwww.
# 35                    wwwwwwwww,wwwwwwwwwwwww;wwwwww.
# 36  www“wwww“,“wwww”,“wwwww”,“ww”w“ww”wwwwwwwwwwww...
# 37         wwwwwwwwwwwwww:w,w,w,w,w,w,wwwwwwww,wwwww.
# 38                                   w,wwww,wwwwwwww.
# 39                               wwwwwwwwwwwwwwwwwww.
# 40  wwwwwwwwwwwwwwwww,www,wwwww,ww,www,ww,www,wwww...
# 41                                               ¿ww?
# 42                                                ww.
# 43                              wwwwwwwwwwwwww,wwwww.
# 44                               wwwwwwwwwwwwwwwwwww.
# 45   wwwwwwwwww,wwwwwwwwwwwwww,wwwwwwwwwwwwwwwwwwwww.
# 46                                wwwwwwwwww,wwwwwww.
# 47                                      wwwwwwwwwwww.
# 48                   wwwwwwwwww,wwwwwwwwww,ww,wwwwww.
# 49                      wwwwwwwwwwwwww,wwwwwww,ww,ww.
# 50                                          wwwwwwww.
# 51         wwwwwwwwwwwwww,wwwwwwww,wwwwwwwww,wwwwwww.
# 52                          w,w,w,w,w,wwwwwwwwww,www.
# 53  wwwww,wwwwwwwwww,wwwwwwww,wwww,wwwwwwwwwwwwwww...
# 54                                              ww,w.
#
#                                                   pos
# 0                         NAXXPNPANCNJ,ANRXVPJNNPAAN.
# 1                               ANVNJDJCDXJVJPANPANX.
# 2                      PDDVAJNPANJ,JPNRPANVPANJJC“J”.
# 3                                NN,ANCNPV,CANRVPANJ.
# 4   PVPAJNPANCNRDVCAANPANPNX,AN,XVPANJ,DJ,CCRVVNJC...
# 5                 CANJCANPN–N,N–XNPANPANPNJPXCANPANJ.
# 6   PAN“X”,N,V:“ANDXPVPAX”CPAXXPMRVCANXX:“NCNJPAN”...
# 7                            AJNPANJDVPNCANPAXXXAJPN.
# 8                           CVAJNPVX,N“J”CJPANRXVPAN.
# 9                                    ANXVPNJPAN,PAAN.
# 10          ANJPANCAN,RVVCDXANVCVRJ,PNPRJ,PNPAJNJCPN.
# 11                                         ANJCPNJPN.
# 12  PDCAJNCJPANJPAN,JP“X”CAN“X”,DXNCNPN,CDDJPANPAJ...
# 13                                       ANPANDRVPRJ.
# 14                         PN,VJPRJCJ,CCANRVPAN,RVAN.
# 15  XJPAX,CPXJ,PANN,CAN,ANCANXJ,VJPAJNJCJ,VRANJXVD...
# 16           VDANPNJ,VDANPMCMMNPN,PNJX,PAJNPVCRJ“NX”.
# 17                                        ANXVPNCANJ.
# 18                         JNXXVDPCANJXXAN,NXJPANPNJ.
# 19                            VANPAN,CANJPVDPA“XX”DJ.
# 20       ANPANCNJVPCVNPANCXPN,XJVANPVCANJPANPNJVNDCJ.
# 21                  XJPVJANJAN,CANRVPANPNPNCVPANRAND.
# 22                                 DN,DRVPVANJCVANPN.
# 23                                   PRRVPAANPAXPVAN.
# 24                 ANPD,XDJ,CPDVANJPNPMNCVJNPAN,ANXJ.
# 25                                      ANJXJPXJPAND.
# 26                           AXXJVANPANJPNPANPNCVNJJ.
# 27                                  VDPANPN,CANVPANJ.
# 28                                    RVC,ANPRCDANPR.
# 29                   PVAX,ANRVDPN,RVPRCPAN,XAN,A“NX”.
# 30                                     ANJPNPNCNJXAN.
# 31   ¿PR,D,AN,AN,PNA“N”,CARDXNPANVAN,ANJPAN,AN,AN,AN?
# 32                               DPMNPNPAXCANPNRVDMN.
# 33                                            DXNPNJ.
# 34            AX,AX,ANXCPAAX,ANJ,ANPX,AX,XVANJCANRXV.
# 35                    ANXAJCRXV,CVPANANJCVPVN;NPAJNJ.
# 36  ANC“XPAX“,“XPRX”,“XJPAN”,“NJ”C“NJ”XNRXVPANJPAJ...
# 37         XVPANRRXVPNJCJ:X,N,N,N,N,N,PJCJCPRJ,NPNPV.
# 38                                   C,DPAN,CVANPAAN.
# 39                               CDCANPANJCCAJNRVANJ.
# 40  DVANCPANJRVVANCAN,VAN,ANPAN,AN,ANJ,AN,ANJ,ANJP...
# 41                                               ¿NJ?
# 42                                                PN.
# 43                              ARDVPANXCVJPAN,PANCN.
# 44                               PRNVANPANCPANAXJNCN.
# 45   ANPNCPNJCJ,RDRXVXVDANRVPN,PNPNPRANCANRVPNJCXDDN.
# 46                                VPJNDDPVAN,CANJPAN.
# 47                                      ANJPJNCJNJPN.
# 48                   NDXJJVPNAN,PVPNJPVAAN,NJ,CDCANJ.
# 49                      DANJDXDJPAJNPN,CPANPAN,AN,AN.
# 50                                          ANJPNDVV.
# 51         PANJANPANVTDAN,VCVNCNPV,RXCDVPMPN,NCNJPAN.
# 52                          X,V,V,V,X,VDNJCJVANN,XNJ.
# 53  XNPVN,PDVANPNCAN,PVANCVAN,PVAN,PVANPPRCPRCAANC...
# 54                                              XX,N.
